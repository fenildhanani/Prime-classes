# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests

URL = "https://stephen-king-api.onrender.com/api/books"

res = requests.get(URL, timeout=10)

print(res.status_code)
print(res)
# Out:
# 200
# <Response [200]>

# %%
data = res.json()

# %%
import pandas as pd
df = pd.json_normalize(json_data["data"])
df = df[["id","Title","Year","ISBN"]]

# %%
df
# Out:
#     id            Title  Year                  ISBN
# 0    1           Carrie  1974     978-0-385-08695-0
# 1    2      Salem's Lot  1975     978-0-385-00751-1
# 2    3      The Shining  1977     978-0-385-12167-5
# 3    4             Rage  1977     978-0-451-07645-8
# 4    5        The Stand  1978     978-0-385-12168-2
# ..  ..              ...   ...                   ...
# 59  60        Elevation  2018     978-1-98210-231-9
# 60  61    The Institute  2019     978-1-98211-056-7
# 61  62            Later  2021     978-1-78909-649-1
# 62  63    Billy Summers  2021     978-1-982-17361-6
# 63  72  The Roopak Zone  1979  978-0-670-26069697-5
#
# [64 rows x 4 columns]

# %%
import requests
URL = "https://jsonplaceholder.typicode.com/users"
res = requests.get(URL, timeout=10)

print(res.status_code)
print(res)
# Out:
# 200
# <Response [200]>

# %%
data = res.json()
print(data)
# import datafrme as df
# Out:
# [{'id': 1, 'name': 'Leanne Graham', 'username': 'Bret', 'email': 'Sincere@april.biz', 'address': {'street': 'Kulas Light', 'suite': 'Apt. 556', 'city': 'Gwenborough', 'zipcode': '92998-3874', 'geo': {'lat': '-37.3159', 'lng': '81.1496'}}, 'phone': '1-770-736-8031 x56442', 'website': 'hildegard.org', 'company': {'name': 'Romaguera-Crona', 'catchPhrase': 'Multi-layered client-server neural-net', 'bs': 'harness real-time e-markets'}}, {'id': 2, 'name': 'Ervin Howell', 'username': 'Antonette', 'email': 'Shanna@melissa.tv', 'address': {'street': 'Victor Plains', 'suite': 'Suite 879', 'city': 'Wisokyburgh', 'zipcode': '90566-7771', 'geo': {'lat': '-43.9509', 'lng': '-34.4618'}}, 'phone': '010-692-6593 x09125', 'website': 'anastasia.net', 'company': {'name': 'Deckow-Crist', 'catchPhrase': 'Proactive didactic contingency', 'bs': 'synergize scalable supply-chains'}}, {'id': 3, 'name': 'Clementine Bauch', 'username': 'Samantha', 'email': 'Nathan@yesenia.net', 'address': {'street': 'Douglas Ext
# ...

# %%
print(res.status_code)
print(res.headers.get("Content-Type"))
print(res.text[:100])
# Out:
# 200
# application/json; charset=utf-8
# [
#   {
#     "id": 1,
#     "name": "Leanne Graham",
#     "username": "Bret",
#     "email": "Sincere@april.

# %%
data = res.json()

print(data)
# Out:
# [{'id': 1, 'name': 'Leanne Graham', 'username': 'Bret', 'email': 'Sincere@april.biz', 'address': {'street': 'Kulas Light', 'suite': 'Apt. 556', 'city': 'Gwenborough', 'zipcode': '92998-3874', 'geo': {'lat': '-37.3159', 'lng': '81.1496'}}, 'phone': '1-770-736-8031 x56442', 'website': 'hildegard.org', 'company': {'name': 'Romaguera-Crona', 'catchPhrase': 'Multi-layered client-server neural-net', 'bs': 'harness real-time e-markets'}}, {'id': 2, 'name': 'Ervin Howell', 'username': 'Antonette', 'email': 'Shanna@melissa.tv', 'address': {'street': 'Victor Plains', 'suite': 'Suite 879', 'city': 'Wisokyburgh', 'zipcode': '90566-7771', 'geo': {'lat': '-43.9509', 'lng': '-34.4618'}}, 'phone': '010-692-6593 x09125', 'website': 'anastasia.net', 'company': {'name': 'Deckow-Crist', 'catchPhrase': 'Proactive didactic contingency', 'bs': 'synergize scalable supply-chains'}}, {'id': 3, 'name': 'Clementine Bauch', 'username': 'Samantha', 'email': 'Nathan@yesenia.net', 'address': {'street': 'Douglas Ext
# ...

# %%
df.head()
# Out:
#    id        Title  Year               ISBN
# 0   1       Carrie  1974  978-0-385-08695-0
# 1   2  Salem's Lot  1975  978-0-385-00751-1
# 2   3  The Shining  1977  978-0-385-12167-5
# 3   4         Rage  1977  978-0-451-07645-8
# 4   5    The Stand  1978  978-0-385-12168-2

# %%
import requests
import pandas as pd

URL = "https://stephen-king-api.onrender.com/api/books"

res = requests.get(URL, timeout=10)

print(res.status_code)

data = read.json()
print(data)

df = pd.DataFrame(data)

print(df.head())
# Out:
# 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 10
#       6 res = requests.get(URL, timeout=10)
#       7
#       8 print(res.status_code)
#       9
# ---> 10 data = read.json()
#      11 print(data)
#      12
#      13 df = pd.DataFrame(data)
#
# NameError: name 'read' is not defined

# %%
data = read.json()
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 data = read.json()
#       2 print(data)
#
# NameError: name 'read' is not defined

# %%
import requests
URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)
print(res.status_code)
print(res)
# Out:
# 200
# <Response [200]>

# %%
if res.status_code == 200:
    print(res.headers)

with open("scrape2_data/data2.html", "w", encoding="utf-8") as f:
    f.write(res.text)
    # print(res.content)
    # print(res.text)
# Out:
# {'Date': 'Mon, 24 Aug 2026 06:59:05 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=5UlptMSllTtvlT%2FBofNg3ivNeujvoq1MLwNP4ySt8gg%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1787554744"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=5UlptMSllTtvlT%2FBofNg3ivNeujvoq1MLwNP4ySt8gg%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1787554744"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': 'a30078e21bbf85b4-BOM', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
from bs4 import BeautifulSoup

with open("scraped3_data/data.html", "r") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, "lxml")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[81], line 3
#       1 from bs4 import BeautifulSoup
#       2
# ----> 3 with open("scraped3_data/data.html", "r") as f:
#       4     html_content = f.read()
#       5
#       6 soup = BeautifulSoup(html_content, "lxml")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scraped3_data/data.html'

# %%
# soup.find("h3")
# soup.h1
# soup.find_all("h3")

# all_h3 = soup.find_all("h3")

# for h3 in all_h3:
#     name = h3.get_text(strip = True)
    # print(h3.find_parent("div"))
    # h3.find_next("div").select("span.country_population")
    # population = h3.find_next("div").select("span.country_population")[0].get_text(strip = True)
    # population = h3.find_next("div").select_one("span.country_population")[0].get_text(strip = True)
    # all_countrt.append([name,population])
 
all_h3 = soup.find_all("h3")

all_countries = []

for h3 in all_h3:
    name = h3.get_text(strip=True)
    # print(h3.find_parent("div")["class"])

    population = h3.find_next("div").select("span.country-population")[0].get_text(strip=True)
    # print(h3.find_next("div").select_one("span.country-population").get_text(strip=True))

    all_countries.append([name, population])

# %%
all_countries
# Out:
# [['Andorra', '84000'],
#  ['United Arab Emirates', '4975593'],
#  ['Afghanistan', '29121286'],
#  ['Antigua and Barbuda', '86754'],
#  ['Anguilla', '13254'],
#  ['Albania', '2986952'],
#  ['Armenia', '2968000'],
#  ['Angola', '13068161'],
#  ['Antarctica', '0'],
#  ['Argentina', '41343201'],
#  ['American Samoa', '57881'],
#  ['Austria', '8205000'],
#  ['Australia', '21515754'],
#  ['Aruba', '71566'],
#  ['Åland', '26711'],
#  ['Azerbaijan', '8303512'],
#  ['Bosnia and Herzegovina', '4590000'],
#  ['Barbados', '285653'],
#  ['Bangladesh', '156118464'],
#  ['Belgium', '10403000'],
#  ['Burkina Faso', '16241811'],
#  ['Bulgaria', '7148785'],
#  ['Bahrain', '738004'],
#  ['Burundi', '9863117'],
#  ['Benin', '9056010'],
#  ['Saint Barthélemy', '8450'],
#  ['Bermuda', '65365'],
#  ['Brunei', '395027'],
#  ['Bolivia', '9947418'],
#  ['Bonaire', '18012'],
#  ['Brazil', '201103330'],
#  ['Bahamas', '301790'],
#  ['Bhutan', '699847'],
#  ['Bouvet Island', '0'],
#  ['Botswana', '2029307'],
# ...

# %%
import pandas as pd

df = pd.DataFrame(all_countries, columns=["Name", "Population"])

# %%
df.to_csv("cleaned_data/data.csv", index=False)

# %%
import requests
from bs4 import BeautifulSoup

# %%
page_count = 1

while True:
    URL = f"https://quotes.toscrape.com/page/{page_count}/"
    res = requests.get(URL)
    
    soup = BeautifulSoup(res.text, "lxml")
    quotes = soup.select("div.quote")

    if not quotes:
        print("no valid pages anymore..")
        break

    with open(f"scrape_data/quotes{page_count}.html", "wb") as f:
        f.write(res.content)
        print(f"downloaded data from page{page_count}")

    page_count = page_count + 1
# Out:
# downloaded data from page1
# downloaded data from page2
# downloaded data from page3
# downloaded data from page4
# downloaded data from page5
# downloaded data from page6
# downloaded data from page7
# downloaded data from page8
# downloaded data from page9
# downloaded data from page10
# no valid pages anymore..

# %%
import lxml
print(lxml.__version__)

# %%
from bs4 import BeautifulSoup

with open("scrape_data/quotes1.html", "rb") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, "lxml")

# %%
all_quotes = soup.select("div.quote")
life_quotes = []

for q in all_quotes:
    all_tags = []

    for tag in q.select(".tags .tag"):
        all_tags.append(tag.get_text())

    if "life" in all_tags:
        text = q.select_one("span.text").get_text()
        author = q.select_one("small.author").get_text()
        life_quotes.append([text, author])

print(life_quotes)

# %%
life_quotes = []

page_count = 1

while True:

    try:
        with open(f"scrape_data/quotes{page_count}.html", "rb") as f:
            html_content = f.read()
    except FileNotFoundError:
        break

    soup = BeautifulSoup(html_content, "lxml")

    all_quotes = soup.select("div.quote")

    if not all_quotes:
        break

    for q in all_quotes:
        all_tags = []

        for tag in q.select(".tags .tag"):
            all_tags.append(tag.get_text())

        if "life" in all_tags:
            text = q.select_one("span.text").get_text()
            author = q.select_one("small.author").get_text()

            life_quotes.append([text, author])

    page_count = page_count + 1

print(life_quotes)
# Out:
# [['“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”', 'Albert Einstein'], ['“It is better to be hated for what you are than to be loved for what you are not.”', 'André Gide'], ["“This life is what you make it. No matter what, you're going to mess up sometimes, it's a universal truth. But the good part is you get to decide how you're going to mess it up. Girls will be your friends - they'll act like it anyway. But just remember, some come, some go. The ones that stay with you through everything - they're your true best friends. Don't let go of them. Also remember, sisters make the best friends in the world. As for lovers, well, they'll come and go too. And baby, I hate to say it, most of them - actually pretty much all of them are going to break your heart, but you can't give up because if you give up, you'll never find your soulmate. You'll never find that half who makes you whole and that goes for eve
# ...

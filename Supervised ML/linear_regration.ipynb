# %%
import pandas as pd
import seaborn as sns

# %%
import os

print(os.getcwd())
# Out:
# D:\AI_ML\Supervised ML

# %%
# Out:
# False

# %% [raw]
# import os
#
# for root, dirs, files in os.walk(r"D:\AI_ML"):
#     if "insurance.csv" in files:
#         print("Found:", os.path.join(root, "insurance.csv"))

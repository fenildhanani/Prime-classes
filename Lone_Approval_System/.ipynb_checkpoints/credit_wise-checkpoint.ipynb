# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df =pd.read_csv("loan_approval_data.csv")

# %%
df
# Out:
#      loan_id  age  annual_income  employment_years employment_type education  \
# 0      10001   59       153090.0              18.0        Business   Diploma
# 1      10002   49        29302.0               3.0        Salaried   Diploma
# 2      10003   35        85506.0               9.0        Business    Master
# 3      10004   63        59157.0               0.0   Self_Employed    Master
# 4      10005   28        72917.0              22.0        Business       PhD
# ..       ...  ...            ...               ...             ...       ...
# 995    10996   53       123111.0              19.0        Contract   Diploma
# 996    10997   22       156299.0               2.0   Self_Employed    Master
# 997    10998   34        54041.0               5.0        Contract  Bachelor
# 998    10999   60       106920.0               6.0        Contract       NaN
# 999    11000   60        83681.0              19.0        Contract   Diploma
#
#     marital_status  dependents  credit_score  existing_loans  ...  \
# 0          Married         2.0         484.0               3  ...
# 1           Single         NaN         368.0               5  ...
# 2          Married         4.0         429.0               5  ...
# 3          Married         4.0         633.0               2  ...
# 4           Single         2.0         453.0               0  ...
# ..             ...         ...           ...             ...  ...
# 995       Divorced         1.0         542.0               4  ...
# 996       Divorced         0.0         372.0               0  ...
# 997        Married         3.0         778.0               3  ...
# 998        Married         4.0         400.0               1  ...
# 999       Divorced         2.0         813.0               3  ...
#
#      monthly_debt_payment  loan_amount  loan_term_months  interest_rate  \
# 0                  2393.0      84360.0                12            NaN
# 1                  3920.0      74835.0                84          20.90
# 2                     NaN     117424.0                48          16.34
# 3                  7382.0     144190.0                72          12.74
# 4                  1215.0      61911.0                24           6.24
# ..                    ...          ...               ...            ...
# 995                 207.0     173521.0                72          19.67
# 996                   NaN      66606.0                60          21.86
# 997                5756.0      23891.0                12          10.35
# 998                   NaN     188187.0                24          17.22
# 999                5152.0     106732.0                48           7.40
#
#      down_payment  home_ownership bank_account_months  late_payments  \
# 0         42816.0             Own               236.0            4.0
# 1         23924.0            Rent                44.0            3.0
# 2         44112.0        Mortgage                97.0            9.0
# 3          9910.0             Own                 NaN            NaN
# 4          1778.0             NaN               120.0            2.0
# ..            ...             ...                 ...            ...
# 995           NaN        Mortgage                57.0            4.0
# 996       35989.0            Rent               196.0            1.0
# 997       30183.0        Mortgage               228.0            2.0
# 998       20758.0        Mortgage               119.0            7.0
# 999        1082.0             Own                95.0            3.0
#
#      loan_purpose loan_approved
# 0        Personal           Yes
# 1       Education            No
# 2       Education           Yes
# 3        Personal            No
# 4         Vehicle           Yes
# ..            ...           ...
# 995       Vehicle            No
# 996          Home            No
# 997      Personal           Yes
# 998       Medical           Yes
# 999     Education            No
#
# [1000 rows x 21 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_id               1000 non-null   int64
#  1   age                   1000 non-null   int64
#  2   annual_income         950 non-null    float64
#  3   employment_years      950 non-null    float64
#  4   employment_type       1000 non-null   str
#  5   education             950 non-null    str
#  6   marital_status        1000 non-null   str
#  7   dependents            950 non-null    float64
#  8   credit_score          950 non-null    float64
#  9   existing_loans        1000 non-null   int64
#  10  total_existing_debt   950 non-null    float64
#  11  monthly_debt_payment  950 non-null    float64
#  12  loan_amount           950 non-null    float64
#  13  loan_term_months      1000 non-null   int64
#  14  interest_rate         950 non-null    float64
#  15  down_payment          950 non-null    float64
#  16  home_ownership        950 non-null    str
#  17  bank_account_months   950 non-null    float64
#  18  late_payments         950 non-null    float64
#  19  loan_purpose          950 non-null    str
#  20  loan_approved         1000 non-null   str
# dtypes: float64(11), int64(4), str(6)
# memory usage: 200.6 KB
#             loan_id          age  annual_income  employment_years  dependents  \
# count   1000.000000  1000.000000     950.000000        950.000000  950.000000
# mean   10500.500000    42.515000  101812.450526         14.982105    1.989474
# std      288.819436    12.611059   47049.010317          8.956439    1.406703
# min    10001.000000    21.000000   18126.000000          0.000000    0.000000
# 25%    10250.750000    32.000000   61599.250000          7.000000    1.000000
# 50%    10500.500000    43.000000  100924.500000         15.000000    2.000000
# 75%    10750.250000    53.000000  143976.250000         22.000000    3.000000
# max    11000.000000    64.000000  179779.000000         30.000000    4.000000
#
#        credit_score  existing_loans  total_existing_debt  \
# count    950.000000     1000.000000           950.000000
# mean     570.077895        2.446000         49118.830526
# std      160.887981        1.706457         29171.032317
# min      300.000000        0.000000             2.000000
# 25%      429.250000        1.000000         23353.000000
# 50%      558.000000        2.000000         47202.500000
# 75%      712.750000        4.000000         75384.250000
# max      850.000000        5.000000         99862.000000
#
#        monthly_debt_payment    loan_amount  loan_term_months  interest_rate  \
# count            950.000000     950.000000       1000.000000     950.000000
# mean            4050.595789   98147.588421         49.236000      13.757400
# std             2272.574738   55599.710669         23.244539       4.599428
# min               10.000000    5209.000000         12.000000       5.500000
# 25%             2107.250000   49796.750000         36.000000       9.955000
# 50%             4110.000000   98608.000000         48.000000      13.825000
# 75%             5917.000000  144150.500000         72.000000      17.617500
# max             7986.000000  199904.000000         84.000000      21.980000
#
#        down_payment  bank_account_months  late_payments
# count    950.000000           950.000000     950.000000
# mean   24057.655789           119.393684       4.317895
# std    14241.369891            67.980679       2.880112
# min        5.000000             3.000000       0.000000
# 25%    11555.000000            57.250000       2.000000
# 50%    23409.500000           119.000000       4.000000
# 75%    36396.500000           178.000000       7.000000
# max    49979.000000           239.000000       9.000000

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['str']).columns

# categorical_cols = df.select_dtypes(include=["float64"]).columns
# numerical_cols = df.select_dtypes(include=["number"]).columns

# %%
# categorical_cols.size + numerical_cols.size

# %%
categorical_cols
# Out:
# Index(['employment_type', 'education', 'marital_status', 'home_ownership',
#        'loan_purpose', 'loan_approved'],
#       dtype='str')

# %%
numerical_cols
# Out:
# Index(['loan_id', 'age', 'annual_income', 'employment_years', 'dependents',
#        'credit_score', 'existing_loans', 'total_existing_debt',
#        'monthly_debt_payment', 'loan_amount', 'loan_term_months',
#        'interest_rate', 'down_payment', 'bank_account_months',
#        'late_payments'],
#       dtype='str')

# %%
from sklearn.impute import SimpleImputer

num_imp = SimpleImputer(strategy="mean")
df[numerical_cols] = num_imp.fit_transform(df[numerical_cols])

# %%
cat_imp = SimpleImputer(strategy="most_frequent")
df[categorical_cols] = cat_imp.fit_transform(df[categorical_cols])

# %%
# df.head()
df.isnull().sum()
# Out:
# loan_id                 0
# age                     0
# annual_income           0
# employment_years        0
# employment_type         0
# education               0
# marital_status          0
# dependents              0
# credit_score            0
# existing_loans          0
# total_existing_debt     0
# monthly_debt_payment    0
# loan_amount             0
# loan_term_months        0
# interest_rate           0
# down_payment            0
# home_ownership          0
# bank_account_months     0
# late_payments           0
# loan_purpose            0
# loan_approved           0
# dtype: int64

# %%
print(categorical_cols)
# Out:
# Index(['annual_income', 'employment_years', 'dependents', 'credit_score',
#        'total_existing_debt', 'monthly_debt_payment', 'loan_amount',
#        'interest_rate', 'down_payment', 'bank_account_months',
#        'late_payments'],
#       dtype='str')
